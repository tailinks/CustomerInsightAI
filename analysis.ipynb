# %% [markdown]
# <h2>Introduction</h2>
# <p>In this Jupyter notebook, we explore the e-commerce customer behavior dataset. Our objective is to understand customer purchasing patterns, preferences, and segmentations. The insights from this analysis will guide us in selecting the most appropriate models for further exploration and prediction.</p>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
file_path = 'E-commerce Customer Behavior - Sheet1.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataframe
data_head = data.head()

data_head
# Out:
#    Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0          101  Female   29       New York            Gold      1120.20
# 1          102    Male   34    Los Angeles          Silver       780.50
# 2          103  Female   43        Chicago          Bronze       510.75
# 3          104    Male   30  San Francisco            Gold      1480.30
# 4          105    Male   27          Miami          Silver       720.40
#
#    Items Purchased  Average Rating  Discount Applied  \
# 0               14             4.6              True
# 1               11             4.1             False
# 2                9             3.4              True
# 3               19             4.7             False
# 4               13             4.0              True
#
#    Days Since Last Purchase Satisfaction Level
# 0                        25          Satisfied
# 1                        18            Neutral
# 2                        42        Unsatisfied
# ...

# %%
# Summary of the dataset
data_description = data.describe()

data_description
# Out:
#        Customer ID         Age  Total Spend  Items Purchased  Average Rating  \
# count   350.000000  350.000000   350.000000       350.000000      350.000000
# mean    275.500000   33.597143   845.381714        12.600000        4.019143
# std     101.180532    4.870882   362.058695         4.155984        0.580539
# min     101.000000   26.000000   410.800000         7.000000        3.000000
# 25%     188.250000   30.000000   502.000000         9.000000        3.500000
# 50%     275.500000   32.500000   775.200000        12.000000        4.100000
# 75%     362.750000   37.000000  1160.600000        15.000000        4.500000
# max     450.000000   43.000000  1520.100000        21.000000        4.900000
#
#        Days Since Last Purchase
# count                350.000000
# mean                  26.588571
# std                   13.440813
# min                    9.000000
# 25%                   15.000000
# 50%                   23.000000
# 75%                   38.000000
# ...

# %%
# Data types and missing values
data_types = data.dtypes
missing_values = data.isnull().sum()
data_types, missing_values
# Out:
# (Customer ID                   int64
#  Gender                       object
#  Age                           int64
#  City                         object
#  Membership Type              object
#  Total Spend                 float64
#  Items Purchased               int64
#  Average Rating              float64
#  Discount Applied               bool
#  Days Since Last Purchase      int64
#  Satisfaction Level           object
#  dtype: object,
#  Customer ID                 0
#  Gender                      0
#  Age                         0
#  City                        0
#  Membership Type             0
#  Total Spend                 0
#  Items Purchased             0
#  Average Rating              0
#  Discount Applied            0
#  Days Since Last Purchase    0
#  Satisfaction Level          2
#  dtype: int64)

# %% [markdown]
# <h2>Insights and Observations</h2>
# <p>Based on the exploratory data analysis, we observe the following:</p>
# <ul>
#     <li>The dataset features a mix of numerical and categorical attributes.</li>
#     <li>Most features exhibit a fairly normal distribution, with some skewness present in attributes like 'Total Spend'.</li>
#     <li>There is a lack of significant correlations between most numerical features, indicating that multicollinearity might not be a major concern for predictive modeling.</li>
#     <li>The minimal number of missing values in the 'Satisfaction Level' suggests that simple imputation methods could be effective.</li>
# </ul>

# %%
# Visualizations
# Histograms for numerical features
plt.figure(figsize=(12, 8))
for i, col in enumerate(['Age', 'Total Spend', 'Items Purchased', 'Average Rating', 'Days Since Last Purchase']):
    plt.subplot(2, 3, i + 1)
    sns.histplot(data[col], kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()

# Bar charts for categorical features (excluding Customer ID)
plt.figure(figsize=(12, 8))
for i, col in enumerate(['Gender', 'City', 'Membership Type', 'Discount Applied', 'Satisfaction Level']):
    plt.subplot(2, 3, i + 1)
    sns.countplot(x=col, data=data)
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45)
plt.tight_layout()

# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# Preparing the output for the initial sections
data_head, data_description, data_types, missing_values
# Out:
# /var/folders/zw/8vt1b0xx2qj59jsws1wlsxp00000gn/T/ipykernel_54919/3194745072.py:21: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
# (   Customer ID  Gender  Age           City Membership Type  Total Spend  \
#  0          101  Female   29       New York            Gold      1120.20
#  1          102    Male   34    Los Angeles          Silver       780.50
#  2          103  Female   43        Chicago          Bronze       510.75
#  3          104    Male   30  San Francisco            Gold      1480.30
#  4          105    Male   27          Miami          Silver       720.40
#
#     Items Purchased  Average Rating  Discount Applied  \
#  0               14             4.6              True
#  1               11             4.1             False
# ...

# %% [markdown]
# <h2>Recommendations for Modeling</h2>
# <p>Given the insights from the EDA, we recommend the following modeling approaches:</p>
# <ol>
#     <li><strong>Customer Segmentation:</strong> Utilize clustering algorithms such as K-Means or hierarchical clustering to segment customers based on their purchasing behavior and demographics.</li>
#     <li><strong>Predicting Customer Satisfaction:</strong> Employ classification models (e.g., Logistic Regression, Decision Trees, Random Forest) to predict the 'Satisfaction Level' from other customer attributes.</li>
#     <li><strong>Predictive Analysis:</strong> Regression models could be suitable for predicting 'Total Spend' or 'Items Purchased' based on various customer features.</li>
# </ol>

# %% [markdown]
# <h2>Conclusion</h2>
# <p>The exploratory data analysis provided valuable insights into the dataset, guiding us towards potential modeling approaches. The subsequent phase of the project will involve data preprocessing, including handling missing values and encoding categorical variables, followed by the development and evaluation of models based on the recommendations provided.</p>
